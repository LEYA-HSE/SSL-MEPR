# %%
from sklearn.metrics import classification_report
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np
from pathlib import Path
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm

# ==================== METRICS ====================
def ccc(y_true, y_pred):
    """
    This function calculates loss based on concordance correlation coefficient of two series: 'ser1' and 'ser2'
    TensorFlow methods are used
    """

    y_true_mean = np.mean(y_true)
    y_pred_mean = np.mean(y_pred)

    y_true_var = np.mean(np.square(y_true-y_true_mean))
    y_pred_var = np.mean(np.square(y_pred-y_pred_mean))

    cov = np.mean((y_true-y_true_mean)*(y_pred-y_pred_mean))

    ccc = np.multiply(2., cov) / (y_true_var + y_pred_var + np.square(y_true_mean - y_pred_mean))
    ccc_loss=np.mean(ccc)
    return ccc_loss

def acc_func(trues, preds):
    # print('acc', trues, preds)
    acc = []
    for i in range(5):
        acc.append(np.abs(trues - preds))
    acc = 1 - np.asarray(acc)
    return np.mean(acc)

def mf1(targets: list[np.ndarray] | np.ndarray, 
                         predicts: list[np.ndarray] | np.ndarray,
                         return_scores: bool = False) -> float | tuple[float, list[float]]:
    """Calculates mean Macro F1 score (emotional multilabel mMacroF1)
    
    Args:
        targets: Targets array (ground truth)
        predicts: Predicts array (model predictions)
        return_scores: If True, returns both mean and per-class scores
        
    Returns:
        float: Mean Macro F1 score across all classes
        or
        tuple[float, list[float]]: If return_scores=True, returns (mean, per_class_scores)
    """
    targets = np.array(targets)
    predicts = np.array(predicts)

    f1_macro_scores = []
    for i in range(predicts.shape[1]):
        cr = classification_report(targets[:, i], predicts[:, i], 
                                         output_dict=True, zero_division=0)
        f1_macro_scores.append(cr['macro avg']['f1-score'])

    if return_scores:
        return np.mean(f1_macro_scores), f1_macro_scores
    return np.mean(f1_macro_scores)


def uar(targets: list[np.ndarray] | np.ndarray,
                    predicts: list[np.ndarray] | np.ndarray,
                    return_scores: bool = False) -> float | tuple[float, list[float]]:
    """Calculates mean Unweighted Average Recall (emotional multilabel mUAR)
    
    Args:
        targets: Targets array (ground truth)
        predicts: Predicts array (model predictions)
        return_scores: If True, returns both mean and per-class scores
        
    Returns:
        float: Mean UAR across all classes
        or
        tuple[float, list[float]]: If return_scores=True, returns (mean, per_class_scores)
    """
    targets = np.array(targets)
    predicts = np.array(predicts)

    uar_scores = []
    for i in range(predicts.shape[1]):
        cr = classification_report(targets[:, i], predicts[:, i],
                                         output_dict=True, zero_division=0)
        uar_scores.append(cr['macro avg']['recall'])

    if return_scores:
        return np.mean(uar_scores), uar_scores
    return np.mean(uar_scores)

def process_predictions(pred_emo, true_emo):
    pred_emo = F.softmax(pred_emo, dim=1).cpu().detach().numpy()
    true_emo = true_emo.cpu().detach().numpy()
    threshold1 = 1 - 1 / 7
    threshold2 = 1 / 7
    mask1 = pred_emo[:, 0] >= threshold1
    transformed = (pred_emo[:, 1:] >= threshold2).astype(int)
    result = np.zeros_like(transformed)
    result[~mask1] = transformed[~mask1]
    pred_emo_bin = result.tolist()
    true_emo_bin = (true_emo[:, 1:] > 0).astype(int).tolist()
    return pred_emo_bin, true_emo_bin

# ==================== DATA LOADING ====================
def load_fiv2(pkl_path, emb_dir):
    import pickle
    with open(pkl_path, 'rb') as f:
        data = pickle.load(f, encoding='latin1')

    trait_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
    records = []
    for name in data['openness'].keys():
        short = name.replace('.mp4', '')
        record = {'video_name': short}
        for key in trait_keys:
            record[key] = data[key][name]
        records.append(record)
    df = pd.DataFrame(records)

    X, y, lengths = [], [], []
    for folder in Path(emb_dir).iterdir():
        for pt_file in folder.glob('*.pt'):
            video_id = pt_file.stem
            if video_id not in df['video_name'].values:
                continue
            emb = torch.load(pt_file, weights_only=True)
            if isinstance(emb, dict):
                emb = emb['emb']
            if torch.isnan(emb).any() or emb.shape != (30, 1024):
                continue
            target = df[df['video_name'] == video_id][trait_keys].values[0].astype('float32')
            X.append(emb)
            y.append(torch.tensor(target))
            lengths.append(torch.tensor(emb.shape[0]))
    return TensorDataset(torch.stack(X), torch.stack(y), torch.stack(lengths))

def load_mosei(csv_path, emb_dir):
    df = pd.read_csv(csv_path).drop(columns=["text", "Other"])
    X, y, lengths = [], [], []
    for _, row in tqdm(df.iterrows(), total=len(df)):
        video_id = row['video_name']
        pt_file = Path(emb_dir) / f"{video_id}.pt"
        if not pt_file.exists():
            continue
        emb = torch.load(pt_file, weights_only=True)
        if isinstance(emb, dict):
            emb = emb['emb']
        if torch.isnan(emb).any() or emb.shape != (30, 1024):
            continue
        X.append(emb)
        y.append(torch.tensor(row.drop("video_name").values.astype('float32')))
        lengths.append(torch.tensor(emb.shape[0]))
    return TensorDataset(torch.stack(X), torch.stack(y), torch.stack(lengths))

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load data
fiv2_train = load_fiv2("Embeddings_emonext/fiv2_embeddings/annotation_training.pkl", "Embeddings_emonext/fiv2_embeddings/train")
fiv2_val = load_fiv2("Embeddings_emonext/fiv2_embeddings/annotation_test.pkl", "Embeddings_emonext/fiv2_embeddings/test")
mosei_train = load_mosei("emo_video/train_full.csv", "Embeddings_emonext/cmu_mosei_embeddings/train")
mosei_val = load_mosei("emo_video/test_full/test_full.csv", "Embeddings_emonext/cmu_mosei_embeddings/test")
# Out:
# 100%|██████████| 16274/16274 [04:20<00:00, 62.37it/s]
# 100%|██████████| 4653/4653 [01:41<00:00, 45.68it/s]

# %%
train_loader_traits = DataLoader(fiv2_train, batch_size=1024, shuffle=True)
val_loader_traits = DataLoader(fiv2_val, batch_size=1024)
train_loader_emo = DataLoader(mosei_train, batch_size=1024, shuffle=True)
val_loader_emo = DataLoader(mosei_val, batch_size=1024)

# %%
# ==================== MODEL ====================

class TransformerBackbone(nn.Module):
    def __init__(self, input_dim=1024, d_model=512, num_layers=3, n_heads=8, dropout=0.2, max_len=30):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embed = nn.Parameter(torch.randn(1, max_len, d_model))
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, dim_feedforward=d_model * 4, dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, lengths):
        x = self.input_proj(x) + self.pos_embed[:, :x.size(1)]
        x = self.encoder(x)
        mask = torch.arange(x.size(1), device=lengths.device)[None, :] < lengths[:, None]
        mask = mask.float().unsqueeze(2)
        summed = (x * mask).sum(dim=1)
        count = mask.sum(dim=1).clamp(min=1)
        pooled = summed / count
        return self.dropout(pooled)


class FrozenTransformerWrapper(nn.Module):
    def __init__(self, scripted_model_path, backbone_type='traits'):
        super().__init__()
        self.model = TransformerBackbone()
        #state_dict = torch.jit.load(scripted_model_path).state_dict()
        state_dict = torch.load(scripted_model_path, weights_only=True)['model_state_dict']
        filtered = {k: v for k, v in state_dict.items() if not k.startswith('fc')}
        self.model.load_state_dict(filtered, strict=False)
        for p in self.model.parameters():
            p.requires_grad = False

    def forward(self, x, lengths):
        return self.model(x, lengths)


class CrossAttentionBlock(nn.Module):
    def __init__(self, d_model=512, n_heads=8, dropout=0.2):
        super().__init__()
        self.attn = nn.MultiheadAttention(d_model, n_heads, dropout=dropout, batch_first=True)
        self.norm = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, q, kv):
        out, _ = self.attn(q, kv, kv)
        return self.norm(q + self.dropout(out))



class MultiTaskFusionModel(nn.Module):
    def __init__(self, trait_model_path="models_checkpoints/fiv2_best_checkpoint.pth", emo_model_path="models_checkpoints/cmu_mosei_best_checkpoint.pth", d_model=512, dropout=0.2):
        super().__init__()
        
        self.trait_model = FrozenTransformerWrapper(trait_model_path)
        self.emo_model = FrozenTransformerWrapper(emo_model_path)

        self.trait_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model, 8, 4*d_model, dropout=dropout, batch_first=True), num_layers=2)
        self.emo_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model, 8, 4*d_model, dropout=dropout, batch_first=True), num_layers=2)

        self.cross1 = CrossAttentionBlock(d_model, 8, dropout)
        self.cross2 = CrossAttentionBlock(d_model, 8, dropout)

        self.shared_mlp = nn.Sequential(
            nn.Linear(2 * d_model, d_model),
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        self.trait_head = nn.Linear(d_model, 5)
        self.emo_head = nn.Linear(d_model, 7)

    def forward(self, x, lengths, task='traits'):
        trait_feat = self.trait_model(x, lengths).unsqueeze(1)
        emo_feat = self.emo_model(x, lengths).unsqueeze(1)

        trait_encoded = self.trait_encoder(trait_feat)
        emo_encoded = self.emo_encoder(emo_feat)

        trait_cross = self.cross1(trait_encoded, emo_encoded)
        emo_cross = self.cross2(emo_encoded, trait_encoded)

        fused = torch.cat([trait_cross, emo_cross], dim=-1).squeeze(1)
        hidden = self.shared_mlp(fused)

        if task == 'traits':
            return self.trait_head(hidden)
        elif task == 'emotions':
            return self.emo_head(hidden)
        else:
            raise ValueError("task must be either 'traits' or 'emotions'")

# %%
# ==================== TRAINING ====================

model = MultiTaskFusionModel().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

criterion_traits = nn.MSELoss()

def weighted_kl_div(log_probs, target_probs, class_weights):
    """
    Manually computes class-weighted KL divergence:
    L = sum_j w_j * q_j * (log q_j - log p_j)
    where q_j is target prob and p_j is predicted prob.
    """
    kl_per_class = target_probs * (torch.log(target_probs + 1e-8) - log_probs)  # (B, C)
    weighted_kl = kl_per_class * class_weights  # apply weights per class
    return weighted_kl.sum(dim=1).mean()  # average over batch

class_weights = torch.tensor([3.0, 10.0, 13.0, 20.0, 2.0, 15.0, 18.0], device=DEVICE)

for epoch in range(1, 201):
    model.train()
    total_loss_emo, total_loss_traits = 0, 0

    for xb, yb, lb in train_loader_emo:
        xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
        optimizer.zero_grad()
        logits = model(xb, lb, task='emotions')
        log_probs = F.log_softmax(logits, dim=1)
        loss = weighted_kl_div(log_probs, yb, class_weights)
        loss.backward()
        optimizer.step()
        total_loss_emo += loss.item()

    for xb, yb, lb in train_loader_traits:
        xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
        optimizer.zero_grad()
        preds = model(xb, lb, task='traits')
        loss = criterion_traits(preds, yb)
        loss.backward()
        optimizer.step()
        total_loss_traits += loss.item()

    # === Validation ===
    model.eval()

    # Emotions
    emo_val_loss, raw_preds, raw_targets = 0, [], []
    with torch.no_grad():
        for xb, yb, lb in val_loader_emo:
            xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
            logits = model(xb, lb, task='emotions')
            log_probs = F.log_softmax(logits, dim=1)
            loss = weighted_kl_div(log_probs, yb, class_weights)
            emo_val_loss += loss.item()
            raw_preds.append(logits)
            raw_targets.append(yb)
    bin_preds, bin_targets = process_predictions(torch.cat(raw_preds), torch.cat(raw_targets))
    f1 = mf1(bin_targets, bin_preds)
    recall = uar(bin_targets, bin_preds)

    # Traits
    trait_val_loss, preds, targets = 0, [], []
    with torch.no_grad():
        for xb, yb, lb in val_loader_traits:
            xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
            out = model(xb, lb, task='traits')
            loss = criterion_traits(out, yb)
            trait_val_loss += loss.item()
            preds.append(out.cpu())
            targets.append(yb.cpu())
    preds = torch.cat(preds).numpy()
    targets = torch.cat(targets).numpy()
    ccc_score = np.mean([ccc(targets[:, i], preds[:, i]) for i in range(5)])
    acc_score = np.mean([acc_func(targets[:, i], preds[:, i]) for i in range(5)])

    print(f"[Epoch {epoch}] Emo Train Loss: {total_loss_emo:.4f} | Emo Val Loss: {emo_val_loss:.4f} | mF1: {f1:.4f} | mUAR: {recall:.4f}")
    print(f"           Trait Train Loss: {total_loss_traits:.4f} | Trait Val Loss: {trait_val_loss:.4f} | CCC: {ccc_score:.4f} | mACC: {acc_score:.4f}")
# Out:
# [Epoch 1] Emo Train Loss: 115.8124 | Emo Val Loss: 61.5978 | mF1: 0.5458 | mUAR: 0.5683
#          Trait Train Loss: 1.0879 | Trait Val Loss: 0.3517 | CCC: 0.0688 | mACC: 0.6307390332221985
# [Epoch 2] Emo Train Loss: 99.2456 | Emo Val Loss: 58.4184 | mF1: 0.5232 | mUAR: 0.5682
#          Trait Train Loss: 0.4226 | Trait Val Loss: 0.0775 | CCC: 0.1132 | mACC: 0.8410788774490356
# [Epoch 3] Emo Train Loss: 95.3153 | Emo Val Loss: 62.0565 | mF1: 0.5429 | mUAR: 0.5702
#          Trait Train Loss: 0.4820 | Trait Val Loss: 0.0757 | CCC: 0.1291 | mACC: 0.8443183898925781
# [Epoch 4] Emo Train Loss: 94.4056 | Emo Val Loss: 62.9582 | mF1: 0.5329 | mUAR: 0.5651
#          Trait Train Loss: 0.5657 | Trait Val Loss: 0.0790 | CCC: 0.1773 | mACC: 0.8419104814529419
# [Epoch 5] Emo Train Loss: 92.7408 | Emo Val Loss: 61.3848 | mF1: 0.5218 | mUAR: 0.5598
#          Trait Train Loss: 0.6871 | Trait Val Loss: 0.0599 | CCC: 0.1956 | mACC: 0.8613244891166687
# [Epoch 6] Emo Train Loss: 92.8208 | Emo Val Loss: 58.5034 | mF1: 0.5251 | mUAR: 0.5664
#          Trait Train Loss: 0.6541 | Trait Val Loss: 0.0604 | CCC: 0.1517 | mACC: 0.8610923886299133
# [Epoch 7] Emo Train Loss: 92.4787 | Emo Val Loss: 58.6076 | mF1: 0.5062 | mUAR: 0.5548
#          Trait Train Loss: 0.5230 | Trait Val Loss: 0.0663 | CCC: 0.1585 | mACC: 0.8547205924987793
# [Epoch 8] Emo Train Loss: 93.3909 | Emo Val Loss: 62.7011 | mF1: 0.5249 | mUAR: 0.5642
#          Trait Train Loss: 0.4438 | Trait Val Loss: 0.0679 | CCC: 0.1750 | mACC: 0.8537896871566772
# [Epoch 9] Emo Train Loss: 93.6289 | Emo Val Loss: 65.3558 | mF1: 0.5412 | mUAR: 0.5636
#          Trait Train Loss: 0.4475 | Trait Val Loss: 0.0676 | CCC: 0.1635 | mACC: 0.854544997215271
# [Epoch 10] Emo Train Loss: 91.2375 | Emo Val Loss: 68.2324 | mF1: 0.5139 | mUAR: 0.5478
#          Trait Train Loss: 0.4463 | Trait Val Loss: 0.0610 | CCC: 0.1503 | mACC: 0.8611005544662476
# [Epoch 11] Emo Train Loss: 92.5250 | Emo Val Loss: 67.4090 | mF1: 0.5407 | mUAR: 0.5640
#          Trait Train Loss: 0.3918 | Trait Val Loss: 0.0696 | CCC: 0.2027 | mACC: 0.8514337539672852
# [Epoch 12] Emo Train Loss: 92.5479 | Emo Val Loss: 63.2824 | mF1: 0.5347 | mUAR: 0.5669
#          Trait Train Loss: 0.3813 | Trait Val Loss: 0.0597 | CCC: 0.2280 | mACC: 0.8627809286117554
# [Epoch 13] Emo Train Loss: 90.1121 | Emo Val Loss: 62.2406 | mF1: 0.5313 | mUAR: 0.5630
#          Trait Train Loss: 0.3751 | Trait Val Loss: 0.0597 | CCC: 0.2026 | mACC: 0.8628646731376648
# [Epoch 14] Emo Train Loss: 89.8477 | Emo Val Loss: 57.8477 | mF1: 0.5233 | mUAR: 0.5661
#          Trait Train Loss: 0.3487 | Trait Val Loss: 0.0528 | CCC: 0.2373 | mACC: 0.8704493641853333
# [Epoch 15] Emo Train Loss: 89.8823 | Emo Val Loss: 60.9540 | mF1: 0.5254 | mUAR: 0.5603
#          Trait Train Loss: 0.3217 | Trait Val Loss: 0.0613 | CCC: 0.2239 | mACC: 0.8600333333015442
# [Epoch 16] Emo Train Loss: 89.5103 | Emo Val Loss: 60.2414 | mF1: 0.5275 | mUAR: 0.5702
#          Trait Train Loss: 0.3171 | Trait Val Loss: 0.0528 | CCC: 0.2550 | mACC: 0.8704956769943237
# [Epoch 17] Emo Train Loss: 89.4113 | Emo Val Loss: 59.5908 | mF1: 0.5273 | mUAR: 0.5610
#          Trait Train Loss: 0.2959 | Trait Val Loss: 0.0576 | CCC: 0.2155 | mACC: 0.8649910688400269
# [Epoch 18] Emo Train Loss: 88.8900 | Emo Val Loss: 64.1943 | mF1: 0.5248 | mUAR: 0.5631
#          Trait Train Loss: 0.3100 | Trait Val Loss: 0.0529 | CCC: 0.2453 | mACC: 0.8712404370307922
# [Epoch 19] Emo Train Loss: 88.9328 | Emo Val Loss: 64.9693 | mF1: 0.5284 | mUAR: 0.5586
#          Trait Train Loss: 0.3165 | Trait Val Loss: 0.0658 | CCC: 0.2266 | mACC: 0.8553606271743774
# [Epoch 20] Emo Train Loss: 88.4558 | Emo Val Loss: 64.1026 | mF1: 0.5288 | mUAR: 0.5656
#          Trait Train Loss: 0.3116 | Trait Val Loss: 0.0543 | CCC: 0.2683 | mACC: 0.8694154620170593
# [Epoch 21] Emo Train Loss: 88.1164 | Emo Val Loss: 64.2892 | mF1: 0.5340 | mUAR: 0.5609
#          Trait Train Loss: 0.3142 | Trait Val Loss: 0.0614 | CCC: 0.2158 | mACC: 0.8608337640762329
# [Epoch 22] Emo Train Loss: 87.4293 | Emo Val Loss: 65.0769 | mF1: 0.5225 | mUAR: 0.5643
#          Trait Train Loss: 0.3000 | Trait Val Loss: 0.0546 | CCC: 0.2448 | mACC: 0.8681120872497559
# [Epoch 23] Emo Train Loss: 87.8351 | Emo Val Loss: 66.2024 | mF1: 0.5352 | mUAR: 0.5600
#          Trait Train Loss: 0.2951 | Trait Val Loss: 0.0621 | CCC: 0.2375 | mACC: 0.8601201176643372
# [Epoch 24] Emo Train Loss: 86.8267 | Emo Val Loss: 63.7639 | mF1: 0.5137 | mUAR: 0.5621
#          Trait Train Loss: 0.2820 | Trait Val Loss: 0.0581 | CCC: 0.2266 | mACC: 0.8646359443664551
# [Epoch 25] Emo Train Loss: 87.8040 | Emo Val Loss: 63.3289 | mF1: 0.5399 | mUAR: 0.5647
#          Trait Train Loss: 0.2897 | Trait Val Loss: 0.0627 | CCC: 0.2660 | mACC: 0.8590589761734009
# [Epoch 26] Emo Train Loss: 87.4829 | Emo Val Loss: 66.1594 | mF1: 0.5187 | mUAR: 0.5569
#          Trait Train Loss: 0.2863 | Trait Val Loss: 0.0615 | CCC: 0.2022 | mACC: 0.8599168658256531
# [Epoch 27] Emo Train Loss: 87.0465 | Emo Val Loss: 67.4353 | mF1: 0.5327 | mUAR: 0.5651
#          Trait Train Loss: 0.2959 | Trait Val Loss: 0.0561 | CCC: 0.2448 | mACC: 0.8675872087478638
# [Epoch 28] Emo Train Loss: 86.4546 | Emo Val Loss: 70.6929 | mF1: 0.5321 | mUAR: 0.5627
#          Trait Train Loss: 0.3063 | Trait Val Loss: 0.0633 | CCC: 0.2078 | mACC: 0.8586590886116028
# [Epoch 29] Emo Train Loss: 86.1668 | Emo Val Loss: 66.0381 | mF1: 0.5372 | mUAR: 0.5623
#          Trait Train Loss: 0.2705 | Trait Val Loss: 0.0613 | CCC: 0.2203 | mACC: 0.8609981536865234
# [Epoch 30] Emo Train Loss: 85.0280 | Emo Val Loss: 65.9259 | mF1: 0.5374 | mUAR: 0.5689
#          Trait Train Loss: 0.2673 | Trait Val Loss: 0.0599 | CCC: 0.2497 | mACC: 0.8621808290481567
# [Epoch 31] Emo Train Loss: 84.9778 | Emo Val Loss: 67.6486 | mF1: 0.5325 | mUAR: 0.5608
#          Trait Train Loss: 0.2762 | Trait Val Loss: 0.0584 | CCC: 0.2771 | mACC: 0.8641066551208496
# [Epoch 32] Emo Train Loss: 83.5200 | Emo Val Loss: 74.9264 | mF1: 0.5455 | mUAR: 0.5641
#          Trait Train Loss: 0.2881 | Trait Val Loss: 0.0660 | CCC: 0.2794 | mACC: 0.8553193807601929
# [Epoch 33] Emo Train Loss: 84.0627 | Emo Val Loss: 69.0332 | mF1: 0.5241 | mUAR: 0.5610
#          Trait Train Loss: 0.2813 | Trait Val Loss: 0.0634 | CCC: 0.2483 | mACC: 0.858623206615448
# [Epoch 34] Emo Train Loss: 83.9653 | Emo Val Loss: 68.9210 | mF1: 0.5411 | mUAR: 0.5636
#          Trait Train Loss: 0.2739 | Trait Val Loss: 0.0584 | CCC: 0.2570 | mACC: 0.8641581535339355
# [Epoch 35] Emo Train Loss: 84.8399 | Emo Val Loss: 68.6791 | mF1: 0.5309 | mUAR: 0.5656
#          Trait Train Loss: 0.2754 | Trait Val Loss: 0.0601 | CCC: 0.2570 | mACC: 0.8625426292419434
# [Epoch 36] Emo Train Loss: 83.7935 | Emo Val Loss: 70.2561 | mF1: 0.5325 | mUAR: 0.5607
#          Trait Train Loss: 0.2816 | Trait Val Loss: 0.0607 | CCC: 0.2434 | mACC: 0.8616100549697876
# [Epoch 37] Emo Train Loss: 82.3184 | Emo Val Loss: 67.7886 | mF1: 0.5268 | mUAR: 0.5638
#          Trait Train Loss: 0.2652 | Trait Val Loss: 0.0619 | CCC: 0.2371 | mACC: 0.8602118492126465
# [Epoch 38] Emo Train Loss: 81.8759 | Emo Val Loss: 72.8569 | mF1: 0.5409 | mUAR: 0.5642
#          Trait Train Loss: 0.2708 | Trait Val Loss: 0.0613 | CCC: 0.2718 | mACC: 0.8608484268188477
# [Epoch 39] Emo Train Loss: 81.3010 | Emo Val Loss: 69.2056 | mF1: 0.5399 | mUAR: 0.5698
#          Trait Train Loss: 0.2714 | Trait Val Loss: 0.0585 | CCC: 0.3086 | mACC: 0.8640919923782349
# [Epoch 40] Emo Train Loss: 81.2870 | Emo Val Loss: 69.7325 | mF1: 0.5424 | mUAR: 0.5660
#          Trait Train Loss: 0.2687 | Trait Val Loss: 0.0649 | CCC: 0.2406 | mACC: 0.856580376625061
# [Epoch 41] Emo Train Loss: 80.4933 | Emo Val Loss: 70.5793 | mF1: 0.5330 | mUAR: 0.5648
#          Trait Train Loss: 0.2631 | Trait Val Loss: 0.0599 | CCC: 0.2715 | mACC: 0.8622992634773254
# [Epoch 42] Emo Train Loss: 80.4039 | Emo Val Loss: 70.7613 | mF1: 0.5404 | mUAR: 0.5613
#          Trait Train Loss: 0.2579 | Trait Val Loss: 0.0599 | CCC: 0.2602 | mACC: 0.8619089126586914
# [Epoch 43] Emo Train Loss: 80.9882 | Emo Val Loss: 70.7215 | mF1: 0.5216 | mUAR: 0.5585
#          Trait Train Loss: 0.2614 | Trait Val Loss: 0.0606 | CCC: 0.2497 | mACC: 0.8617237210273743
# [Epoch 44] Emo Train Loss: 79.7211 | Emo Val Loss: 77.0957 | mF1: 0.5357 | mUAR: 0.5633
#          Trait Train Loss: 0.2711 | Trait Val Loss: 0.0692 | CCC: 0.2412 | mACC: 0.851557731628418
# [Epoch 45] Emo Train Loss: 80.0761 | Emo Val Loss: 71.4152 | mF1: 0.5309 | mUAR: 0.5602
#          Trait Train Loss: 0.2728 | Trait Val Loss: 0.0590 | CCC: 0.2437 | mACC: 0.8638192415237427
# [Epoch 46] Emo Train Loss: 78.8755 | Emo Val Loss: 79.2181 | mF1: 0.5445 | mUAR: 0.5659
#          Trait Train Loss: 0.2644 | Trait Val Loss: 0.0646 | CCC: 0.2815 | mACC: 0.8564826846122742
# [Epoch 47] Emo Train Loss: 78.9720 | Emo Val Loss: 71.0310 | mF1: 0.5260 | mUAR: 0.5577
#          Trait Train Loss: 0.2568 | Trait Val Loss: 0.0548 | CCC: 0.2832 | mACC: 0.8687529563903809
# [Epoch 48] Emo Train Loss: 79.5976 | Emo Val Loss: 72.7709 | mF1: 0.5419 | mUAR: 0.5672
#          Trait Train Loss: 0.2480 | Trait Val Loss: 0.0574 | CCC: 0.2902 | mACC: 0.8653767704963684
# [Epoch 49] Emo Train Loss: 77.9845 | Emo Val Loss: 74.2844 | mF1: 0.5439 | mUAR: 0.5667
#          Trait Train Loss: 0.2557 | Trait Val Loss: 0.0642 | CCC: 0.2913 | mACC: 0.8574657440185547
# [Epoch 50] Emo Train Loss: 77.1149 | Emo Val Loss: 77.6386 | mF1: 0.5352 | mUAR: 0.5586
#          Trait Train Loss: 0.2553 | Trait Val Loss: 0.0603 | CCC: 0.2818 | mACC: 0.8620710372924805
# [Epoch 51] Emo Train Loss: 76.6329 | Emo Val Loss: 77.5951 | mF1: 0.5474 | mUAR: 0.5647
#          Trait Train Loss: 0.2481 | Trait Val Loss: 0.0630 | CCC: 0.2807 | mACC: 0.8589115142822266
# [Epoch 52] Emo Train Loss: 76.5011 | Emo Val Loss: 69.0803 | mF1: 0.5233 | mUAR: 0.5605
#          Trait Train Loss: 0.2311 | Trait Val Loss: 0.0589 | CCC: 0.2861 | mACC: 0.8636810183525085
# [Epoch 53] Emo Train Loss: 76.2287 | Emo Val Loss: 75.2629 | mF1: 0.5349 | mUAR: 0.5604
#          Trait Train Loss: 0.2383 | Trait Val Loss: 0.0627 | CCC: 0.2725 | mACC: 0.8599697947502136
# [Epoch 54] Emo Train Loss: 75.2238 | Emo Val Loss: 77.5449 | mF1: 0.5344 | mUAR: 0.5593
#          Trait Train Loss: 0.2419 | Trait Val Loss: 0.0613 | CCC: 0.2715 | mACC: 0.8612629175186157
# [Epoch 55] Emo Train Loss: 74.8386 | Emo Val Loss: 84.1146 | mF1: 0.5411 | mUAR: 0.5631
#          Trait Train Loss: 0.2610 | Trait Val Loss: 0.0605 | CCC: 0.3050 | mACC: 0.8622878789901733
# [Epoch 56] Emo Train Loss: 73.9977 | Emo Val Loss: 67.6565 | mF1: 0.5253 | mUAR: 0.5673
#          Trait Train Loss: 0.2287 | Trait Val Loss: 0.0589 | CCC: 0.2618 | mACC: 0.8637080192565918
# [Epoch 57] Emo Train Loss: 74.9748 | Emo Val Loss: 77.3923 | mF1: 0.5515 | mUAR: 0.5693
#          Trait Train Loss: 0.2451 | Trait Val Loss: 0.0564 | CCC: 0.2871 | mACC: 0.8673967123031616
# [Epoch 58] Emo Train Loss: 74.0236 | Emo Val Loss: 73.0107 | mF1: 0.5363 | mUAR: 0.5675
#          Trait Train Loss: 0.2396 | Trait Val Loss: 0.0563 | CCC: 0.2732 | mACC: 0.8675217628479004
# [Epoch 59] Emo Train Loss: 74.3134 | Emo Val Loss: 77.3859 | mF1: 0.5405 | mUAR: 0.5649
#          Trait Train Loss: 0.2363 | Trait Val Loss: 0.0574 | CCC: 0.3007 | mACC: 0.8659149408340454
# [Epoch 60] Emo Train Loss: 72.5857 | Emo Val Loss: 85.1889 | mF1: 0.5430 | mUAR: 0.5654
#          Trait Train Loss: 0.2384 | Trait Val Loss: 0.0645 | CCC: 0.2866 | mACC: 0.8574932217597961
# [Epoch 61] Emo Train Loss: 72.2594 | Emo Val Loss: 84.2726 | mF1: 0.5278 | mUAR: 0.5552
#          Trait Train Loss: 0.2409 | Trait Val Loss: 0.0608 | CCC: 0.2785 | mACC: 0.8615075349807739
# [Epoch 62] Emo Train Loss: 71.1447 | Emo Val Loss: 82.3171 | mF1: 0.5326 | mUAR: 0.5587
#          Trait Train Loss: 0.2299 | Trait Val Loss: 0.0566 | CCC: 0.3189 | mACC: 0.8668328523635864
# [Epoch 63] Emo Train Loss: 70.4599 | Emo Val Loss: 83.8522 | mF1: 0.5455 | mUAR: 0.5657
#          Trait Train Loss: 0.2346 | Trait Val Loss: 0.0552 | CCC: 0.3373 | mACC: 0.868808388710022
# [Epoch 64] Emo Train Loss: 69.9517 | Emo Val Loss: 77.2452 | mF1: 0.5338 | mUAR: 0.5641
#          Trait Train Loss: 0.2281 | Trait Val Loss: 0.0595 | CCC: 0.2740 | mACC: 0.8630622625350952
# [Epoch 65] Emo Train Loss: 70.0511 | Emo Val Loss: 84.0722 | mF1: 0.5438 | mUAR: 0.5638
#          Trait Train Loss: 0.2378 | Trait Val Loss: 0.0558 | CCC: 0.3156 | mACC: 0.8679497838020325
# [Epoch 66] Emo Train Loss: 68.7385 | Emo Val Loss: 77.1864 | mF1: 0.5326 | mUAR: 0.5558
#          Trait Train Loss: 0.2276 | Trait Val Loss: 0.0531 | CCC: 0.2876 | mACC: 0.8714392781257629
# [Epoch 67] Emo Train Loss: 69.7419 | Emo Val Loss: 83.8194 | mF1: 0.5404 | mUAR: 0.5622
#          Trait Train Loss: 0.2193 | Trait Val Loss: 0.0606 | CCC: 0.2886 | mACC: 0.8615108728408813
# [Epoch 68] Emo Train Loss: 68.7591 | Emo Val Loss: 89.0547 | mF1: 0.5455 | mUAR: 0.5606
#          Trait Train Loss: 0.2191 | Trait Val Loss: 0.0573 | CCC: 0.3032 | mACC: 0.8659995794296265
# [Epoch 69] Emo Train Loss: 68.4341 | Emo Val Loss: 85.0498 | mF1: 0.5375 | mUAR: 0.5585
#          Trait Train Loss: 0.2150 | Trait Val Loss: 0.0594 | CCC: 0.2983 | mACC: 0.8638221621513367
# [Epoch 70] Emo Train Loss: 67.7718 | Emo Val Loss: 86.3122 | mF1: 0.5386 | mUAR: 0.5603
#          Trait Train Loss: 0.2101 | Trait Val Loss: 0.0539 | CCC: 0.3019 | mACC: 0.8696986436843872
# [Epoch 71] Emo Train Loss: 69.5829 | Emo Val Loss: 80.8408 | mF1: 0.5362 | mUAR: 0.5612
#          Trait Train Loss: 0.2119 | Trait Val Loss: 0.0511 | CCC: 0.2971 | mACC: 0.8737161755561829
# [Epoch 72] Emo Train Loss: 67.4106 | Emo Val Loss: 82.7315 | mF1: 0.5458 | mUAR: 0.5652
#          Trait Train Loss: 0.2106 | Trait Val Loss: 0.0489 | CCC: 0.3129 | mACC: 0.8768144845962524
# [Epoch 73] Emo Train Loss: 66.8905 | Emo Val Loss: 83.7858 | mF1: 0.5362 | mUAR: 0.5583
#          Trait Train Loss: 0.2149 | Trait Val Loss: 0.0575 | CCC: 0.2617 | mACC: 0.8661335110664368
# [Epoch 74] Emo Train Loss: 66.1441 | Emo Val Loss: 87.4752 | mF1: 0.5309 | mUAR: 0.5570
#          Trait Train Loss: 0.2161 | Trait Val Loss: 0.0588 | CCC: 0.3039 | mACC: 0.8638694882392883
# [Epoch 75] Emo Train Loss: 66.6508 | Emo Val Loss: 88.7864 | mF1: 0.5325 | mUAR: 0.5554
#          Trait Train Loss: 0.2137 | Trait Val Loss: 0.0552 | CCC: 0.2808 | mACC: 0.8690140843391418
# [Epoch 76] Emo Train Loss: 66.4691 | Emo Val Loss: 84.2412 | mF1: 0.5370 | mUAR: 0.5610
#          Trait Train Loss: 0.1975 | Trait Val Loss: 0.0561 | CCC: 0.3226 | mACC: 0.8674437403678894
# [Epoch 77] Emo Train Loss: 65.5162 | Emo Val Loss: 92.0370 | mF1: 0.5387 | mUAR: 0.5561
#          Trait Train Loss: 0.2055 | Trait Val Loss: 0.0575 | CCC: 0.3146 | mACC: 0.8655534982681274
# [Epoch 78] Emo Train Loss: 65.4712 | Emo Val Loss: 88.0482 | mF1: 0.5306 | mUAR: 0.5543
#          Trait Train Loss: 0.1968 | Trait Val Loss: 0.0564 | CCC: 0.3016 | mACC: 0.8668054342269897
# [Epoch 79] Emo Train Loss: 64.7732 | Emo Val Loss: 89.5726 | mF1: 0.5388 | mUAR: 0.5576
#          Trait Train Loss: 0.1935 | Trait Val Loss: 0.0550 | CCC: 0.3148 | mACC: 0.8687663078308105
# [Epoch 80] Emo Train Loss: 64.7690 | Emo Val Loss: 86.7671 | mF1: 0.5352 | mUAR: 0.5638
#          Trait Train Loss: 0.1936 | Trait Val Loss: 0.0562 | CCC: 0.3195 | mACC: 0.8669123649597168
# [Epoch 81] Emo Train Loss: 64.3866 | Emo Val Loss: 92.2905 | mF1: 0.5495 | mUAR: 0.5657
#          Trait Train Loss: 0.1947 | Trait Val Loss: 0.0539 | CCC: 0.3167 | mACC: 0.8702448010444641
# [Epoch 82] Emo Train Loss: 63.9284 | Emo Val Loss: 93.1786 | mF1: 0.5400 | mUAR: 0.5618
#          Trait Train Loss: 0.1996 | Trait Val Loss: 0.0608 | CCC: 0.2550 | mACC: 0.8616059422492981
# [Epoch 83] Emo Train Loss: 62.8297 | Emo Val Loss: 94.2340 | mF1: 0.5395 | mUAR: 0.5603
#          Trait Train Loss: 0.2000 | Trait Val Loss: 0.0489 | CCC: 0.3334 | mACC: 0.8762340545654297
# [Epoch 84] Emo Train Loss: 62.7066 | Emo Val Loss: 99.3612 | mF1: 0.5475 | mUAR: 0.5616
#          Trait Train Loss: 0.1978 | Trait Val Loss: 0.0595 | CCC: 0.3160 | mACC: 0.8626477122306824
# [Epoch 85] Emo Train Loss: 61.1700 | Emo Val Loss: 94.4914 | mF1: 0.5369 | mUAR: 0.5574
#          Trait Train Loss: 0.1872 | Trait Val Loss: 0.0573 | CCC: 0.2991 | mACC: 0.8651415109634399
# [Epoch 86] Emo Train Loss: 61.1827 | Emo Val Loss: 99.6512 | mF1: 0.5483 | mUAR: 0.5602
#          Trait Train Loss: 0.1898 | Trait Val Loss: 0.0488 | CCC: 0.3357 | mACC: 0.876623272895813
# [Epoch 87] Emo Train Loss: 61.1296 | Emo Val Loss: 98.3779 | mF1: 0.5321 | mUAR: 0.5572
#          Trait Train Loss: 0.1895 | Trait Val Loss: 0.0588 | CCC: 0.2899 | mACC: 0.8634836077690125
# [Epoch 88] Emo Train Loss: 61.5019 | Emo Val Loss: 102.6138 | mF1: 0.5468 | mUAR: 0.5609
#          Trait Train Loss: 0.1907 | Trait Val Loss: 0.0539 | CCC: 0.3033 | mACC: 0.870167076587677
# [Epoch 89] Emo Train Loss: 60.7041 | Emo Val Loss: 90.0393 | mF1: 0.5330 | mUAR: 0.5577
#          Trait Train Loss: 0.1868 | Trait Val Loss: 0.0513 | CCC: 0.3032 | mACC: 0.8731806874275208
# [Epoch 90] Emo Train Loss: 60.4410 | Emo Val Loss: 99.5384 | mF1: 0.5481 | mUAR: 0.5643
#          Trait Train Loss: 0.1885 | Trait Val Loss: 0.0549 | CCC: 0.3049 | mACC: 0.8683873414993286
# [Epoch 91] Emo Train Loss: 59.8506 | Emo Val Loss: 106.3137 | mF1: 0.5460 | mUAR: 0.5602
#          Trait Train Loss: 0.1831 | Trait Val Loss: 0.0553 | CCC: 0.2508 | mACC: 0.8681988716125488
# [Epoch 92] Emo Train Loss: 60.4189 | Emo Val Loss: 98.5255 | mF1: 0.5469 | mUAR: 0.5628
#          Trait Train Loss: 0.1877 | Trait Val Loss: 0.0513 | CCC: 0.3270 | mACC: 0.8732463717460632
# [Epoch 93] Emo Train Loss: 59.6929 | Emo Val Loss: 102.0558 | mF1: 0.5377 | mUAR: 0.5543
#          Trait Train Loss: 0.1790 | Trait Val Loss: 0.0535 | CCC: 0.2850 | mACC: 0.8702869415283203
# [Epoch 94] Emo Train Loss: 59.5123 | Emo Val Loss: 105.6807 | mF1: 0.5445 | mUAR: 0.5580
#          Trait Train Loss: 0.1795 | Trait Val Loss: 0.0552 | CCC: 0.3167 | mACC: 0.8681867718696594
# [Epoch 95] Emo Train Loss: 59.3606 | Emo Val Loss: 92.8346 | mF1: 0.5316 | mUAR: 0.5551
#          Trait Train Loss: 0.1751 | Trait Val Loss: 0.0542 | CCC: 0.2727 | mACC: 0.8680703043937683
# [Epoch 96] Emo Train Loss: 58.5130 | Emo Val Loss: 104.5450 | mF1: 0.5454 | mUAR: 0.5602
#          Trait Train Loss: 0.1761 | Trait Val Loss: 0.0528 | CCC: 0.3233 | mACC: 0.8707305788993835
# [Epoch 97] Emo Train Loss: 57.8916 | Emo Val Loss: 101.6225 | mF1: 0.5466 | mUAR: 0.5608
#          Trait Train Loss: 0.1748 | Trait Val Loss: 0.0541 | CCC: 0.2860 | mACC: 0.8686506152153015
# [Epoch 98] Emo Train Loss: 57.7597 | Emo Val Loss: 106.3413 | mF1: 0.5449 | mUAR: 0.5584
#          Trait Train Loss: 0.1755 | Trait Val Loss: 0.0494 | CCC: 0.3125 | mACC: 0.8749492764472961
# [Epoch 99] Emo Train Loss: 57.0034 | Emo Val Loss: 104.9713 | mF1: 0.5426 | mUAR: 0.5593
#          Trait Train Loss: 0.1791 | Trait Val Loss: 0.0546 | CCC: 0.2780 | mACC: 0.8681961297988892
# [Epoch 100] Emo Train Loss: 57.0221 | Emo Val Loss: 98.1946 | mF1: 0.5484 | mUAR: 0.5668
#          Trait Train Loss: 0.1750 | Trait Val Loss: 0.0473 | CCC: 0.3090 | mACC: 0.8777405023574829
# [Epoch 101] Emo Train Loss: 55.9385 | Emo Val Loss: 112.1446 | mF1: 0.5459 | mUAR: 0.5581
#          Trait Train Loss: 0.1719 | Trait Val Loss: 0.0525 | CCC: 0.3193 | mACC: 0.8707329034805298
# [Epoch 102] Emo Train Loss: 56.3464 | Emo Val Loss: 100.6124 | mF1: 0.5439 | mUAR: 0.5637
#          Trait Train Loss: 0.1718 | Trait Val Loss: 0.0557 | CCC: 0.2965 | mACC: 0.8670806884765625
# [Epoch 103] Emo Train Loss: 55.0739 | Emo Val Loss: 103.4898 | mF1: 0.5422 | mUAR: 0.5585
#          Trait Train Loss: 0.1691 | Trait Val Loss: 0.0468 | CCC: 0.3296 | mACC: 0.8785284757614136
# [Epoch 104] Emo Train Loss: 56.3712 | Emo Val Loss: 109.4752 | mF1: 0.5477 | mUAR: 0.5595
#          Trait Train Loss: 0.1708 | Trait Val Loss: 0.0601 | CCC: 0.3003 | mACC: 0.8614197969436646
# [Epoch 105] Emo Train Loss: 54.3114 | Emo Val Loss: 94.0881 | mF1: 0.5409 | mUAR: 0.5630
#          Trait Train Loss: 0.1667 | Trait Val Loss: 0.0484 | CCC: 0.3300 | mACC: 0.876168429851532
# [Epoch 106] Emo Train Loss: 54.4576 | Emo Val Loss: 99.6635 | mF1: 0.5434 | mUAR: 0.5607
#          Trait Train Loss: 0.1670 | Trait Val Loss: 0.0490 | CCC: 0.3610 | mACC: 0.8749893307685852
# [Epoch 107] Emo Train Loss: 54.4204 | Emo Val Loss: 99.9083 | mF1: 0.5369 | mUAR: 0.5571
#          Trait Train Loss: 0.1664 | Trait Val Loss: 0.0512 | CCC: 0.2854 | mACC: 0.8726165890693665
# [Epoch 108] Emo Train Loss: 53.5093 | Emo Val Loss: 118.9124 | mF1: 0.5466 | mUAR: 0.5533
#          Trait Train Loss: 0.1658 | Trait Val Loss: 0.0489 | CCC: 0.3317 | mACC: 0.8757537603378296
# [Epoch 109] Emo Train Loss: 55.3979 | Emo Val Loss: 105.1961 | mF1: 0.5412 | mUAR: 0.5578
#          Trait Train Loss: 0.1661 | Trait Val Loss: 0.0496 | CCC: 0.3017 | mACC: 0.8743871450424194
# [Epoch 110] Emo Train Loss: 54.2348 | Emo Val Loss: 97.6485 | mF1: 0.5377 | mUAR: 0.5613
#          Trait Train Loss: 0.1610 | Trait Val Loss: 0.0508 | CCC: 0.3432 | mACC: 0.8730350732803345
# [Epoch 111] Emo Train Loss: 53.3282 | Emo Val Loss: 127.9433 | mF1: 0.5499 | mUAR: 0.5552
#          Trait Train Loss: 0.1611 | Trait Val Loss: 0.0493 | CCC: 0.3402 | mACC: 0.8750753402709961
# [Epoch 112] Emo Train Loss: 54.4451 | Emo Val Loss: 94.7403 | mF1: 0.5264 | mUAR: 0.5591
#          Trait Train Loss: 0.1663 | Trait Val Loss: 0.0569 | CCC: 0.2375 | mACC: 0.8660147786140442
# [Epoch 113] Emo Train Loss: 54.5218 | Emo Val Loss: 103.6548 | mF1: 0.5416 | mUAR: 0.5593
#          Trait Train Loss: 0.1646 | Trait Val Loss: 0.0476 | CCC: 0.3504 | mACC: 0.8776721954345703
# [Epoch 114] Emo Train Loss: 52.0107 | Emo Val Loss: 108.2448 | mF1: 0.5483 | mUAR: 0.5631
#          Trait Train Loss: 0.1580 | Trait Val Loss: 0.0504 | CCC: 0.3427 | mACC: 0.873614490032196
# [Epoch 115] Emo Train Loss: 51.6912 | Emo Val Loss: 116.6817 | mF1: 0.5410 | mUAR: 0.5547
#          Trait Train Loss: 0.1602 | Trait Val Loss: 0.0529 | CCC: 0.3224 | mACC: 0.8700059652328491
# [Epoch 116] Emo Train Loss: 51.6486 | Emo Val Loss: 106.7486 | mF1: 0.5400 | mUAR: 0.5580
#          Trait Train Loss: 0.1576 | Trait Val Loss: 0.0464 | CCC: 0.3536 | mACC: 0.8789712190628052
# [Epoch 117] Emo Train Loss: 50.9726 | Emo Val Loss: 107.5388 | mF1: 0.5439 | mUAR: 0.5607
#          Trait Train Loss: 0.1605 | Trait Val Loss: 0.0501 | CCC: 0.3024 | mACC: 0.8742972612380981
# [Epoch 118] Emo Train Loss: 51.6153 | Emo Val Loss: 119.9244 | mF1: 0.5507 | mUAR: 0.5619
#          Trait Train Loss: 0.1605 | Trait Val Loss: 0.0446 | CCC: 0.3365 | mACC: 0.8813831210136414
# [Epoch 119] Emo Train Loss: 50.7371 | Emo Val Loss: 106.0157 | mF1: 0.5397 | mUAR: 0.5511
#          Trait Train Loss: 0.1602 | Trait Val Loss: 0.0590 | CCC: 0.2643 | mACC: 0.8628813624382019
# [Epoch 120] Emo Train Loss: 50.7418 | Emo Val Loss: 115.1890 | mF1: 0.5459 | mUAR: 0.5585
#          Trait Train Loss: 0.1590 | Trait Val Loss: 0.0441 | CCC: 0.3365 | mACC: 0.8821511268615723
# [Epoch 121] Emo Train Loss: 50.4979 | Emo Val Loss: 111.7327 | mF1: 0.5388 | mUAR: 0.5579
#          Trait Train Loss: 0.1575 | Trait Val Loss: 0.0516 | CCC: 0.3291 | mACC: 0.8717552423477173
# [Epoch 122] Emo Train Loss: 50.7334 | Emo Val Loss: 110.2106 | mF1: 0.5466 | mUAR: 0.5629
#          Trait Train Loss: 0.1536 | Trait Val Loss: 0.0501 | CCC: 0.3034 | mACC: 0.8740398287773132
# [Epoch 123] Emo Train Loss: 50.3704 | Emo Val Loss: 119.2046 | mF1: 0.5459 | mUAR: 0.5593
#          Trait Train Loss: 0.1500 | Trait Val Loss: 0.0455 | CCC: 0.3554 | mACC: 0.8797276616096497
# [Epoch 124] Emo Train Loss: 50.2153 | Emo Val Loss: 110.4942 | mF1: 0.5344 | mUAR: 0.5506
#          Trait Train Loss: 0.1562 | Trait Val Loss: 0.0545 | CCC: 0.2836 | mACC: 0.8686410784721375
# [Epoch 125] Emo Train Loss: 49.5332 | Emo Val Loss: 114.9685 | mF1: 0.5496 | mUAR: 0.5597
#          Trait Train Loss: 0.1534 | Trait Val Loss: 0.0469 | CCC: 0.3598 | mACC: 0.8781428337097168
# [Epoch 126] Emo Train Loss: 50.0179 | Emo Val Loss: 110.6479 | mF1: 0.5393 | mUAR: 0.5558
#          Trait Train Loss: 0.1477 | Trait Val Loss: 0.0465 | CCC: 0.3181 | mACC: 0.8782852292060852
# [Epoch 127] Emo Train Loss: 49.8890 | Emo Val Loss: 114.3567 | mF1: 0.5468 | mUAR: 0.5578
#          Trait Train Loss: 0.1469 | Trait Val Loss: 0.0460 | CCC: 0.3581 | mACC: 0.879290759563446
# [Epoch 128] Emo Train Loss: 49.1013 | Emo Val Loss: 117.8107 | mF1: 0.5345 | mUAR: 0.5523
#          Trait Train Loss: 0.1473 | Trait Val Loss: 0.0482 | CCC: 0.3490 | mACC: 0.8764830827713013
# [Epoch 129] Emo Train Loss: 48.9490 | Emo Val Loss: 115.2241 | mF1: 0.5490 | mUAR: 0.5644
#          Trait Train Loss: 0.1462 | Trait Val Loss: 0.0458 | CCC: 0.3441 | mACC: 0.8796218633651733
# [Epoch 130] Emo Train Loss: 50.2548 | Emo Val Loss: 106.2368 | mF1: 0.5329 | mUAR: 0.5576
#          Trait Train Loss: 0.1532 | Trait Val Loss: 0.0554 | CCC: 0.2451 | mACC: 0.867026150226593
# [Epoch 131] Emo Train Loss: 50.0889 | Emo Val Loss: 122.2767 | mF1: 0.5493 | mUAR: 0.5590
#          Trait Train Loss: 0.1586 | Trait Val Loss: 0.0416 | CCC: 0.3612 | mACC: 0.8847220540046692
# [Epoch 132] Emo Train Loss: 49.2697 | Emo Val Loss: 109.0910 | mF1: 0.5416 | mUAR: 0.5581
#          Trait Train Loss: 0.1537 | Trait Val Loss: 0.0536 | CCC: 0.2948 | mACC: 0.8692282438278198
# [Epoch 133] Emo Train Loss: 48.2545 | Emo Val Loss: 112.2252 | mF1: 0.5454 | mUAR: 0.5578
#          Trait Train Loss: 0.1526 | Trait Val Loss: 0.0427 | CCC: 0.3799 | mACC: 0.8838086128234863
# [Epoch 134] Emo Train Loss: 47.5096 | Emo Val Loss: 121.0666 | mF1: 0.5445 | mUAR: 0.5562
#          Trait Train Loss: 0.1532 | Trait Val Loss: 0.0554 | CCC: 0.3147 | mACC: 0.8664506673812866
# [Epoch 135] Emo Train Loss: 46.6456 | Emo Val Loss: 113.4608 | mF1: 0.5408 | mUAR: 0.5574
#          Trait Train Loss: 0.1455 | Trait Val Loss: 0.0477 | CCC: 0.3299 | mACC: 0.8770731091499329
# [Epoch 136] Emo Train Loss: 47.1992 | Emo Val Loss: 127.8823 | mF1: 0.5429 | mUAR: 0.5548
#          Trait Train Loss: 0.1468 | Trait Val Loss: 0.0471 | CCC: 0.3546 | mACC: 0.8776203393936157
# [Epoch 137] Emo Train Loss: 47.1672 | Emo Val Loss: 128.5194 | mF1: 0.5439 | mUAR: 0.5542
#          Trait Train Loss: 0.1459 | Trait Val Loss: 0.0555 | CCC: 0.3086 | mACC: 0.8669750094413757
# [Epoch 138] Emo Train Loss: 46.6548 | Emo Val Loss: 132.4555 | mF1: 0.5428 | mUAR: 0.5550
#          Trait Train Loss: 0.1462 | Trait Val Loss: 0.0475 | CCC: 0.3434 | mACC: 0.8771222233772278
# [Epoch 139] Emo Train Loss: 46.7901 | Emo Val Loss: 126.5614 | mF1: 0.5483 | mUAR: 0.5600
#          Trait Train Loss: 0.1462 | Trait Val Loss: 0.0487 | CCC: 0.3037 | mACC: 0.8759094476699829
# [Epoch 140] Emo Train Loss: 47.3440 | Emo Val Loss: 117.0783 | mF1: 0.5352 | mUAR: 0.5538
#          Trait Train Loss: 0.1463 | Trait Val Loss: 0.0489 | CCC: 0.3011 | mACC: 0.8755916357040405
# [Epoch 141] Emo Train Loss: 46.7578 | Emo Val Loss: 130.3417 | mF1: 0.5513 | mUAR: 0.5579
#          Trait Train Loss: 0.1458 | Trait Val Loss: 0.0451 | CCC: 0.3635 | mACC: 0.8799694180488586
# [Epoch 142] Emo Train Loss: 45.7566 | Emo Val Loss: 122.2839 | mF1: 0.5399 | mUAR: 0.5563
#          Trait Train Loss: 0.1400 | Trait Val Loss: 0.0489 | CCC: 0.3314 | mACC: 0.8754060864448547
# [Epoch 143] Emo Train Loss: 44.9385 | Emo Val Loss: 123.8976 | mF1: 0.5475 | mUAR: 0.5582
#          Trait Train Loss: 0.1436 | Trait Val Loss: 0.0423 | CCC: 0.3383 | mACC: 0.8840764760971069
# [Epoch 144] Emo Train Loss: 44.5187 | Emo Val Loss: 118.8881 | mF1: 0.5427 | mUAR: 0.5554
#          Trait Train Loss: 0.1464 | Trait Val Loss: 0.0543 | CCC: 0.3067 | mACC: 0.8684921264648438
# [Epoch 145] Emo Train Loss: 45.0811 | Emo Val Loss: 132.1671 | mF1: 0.5444 | mUAR: 0.5533
#          Trait Train Loss: 0.1509 | Trait Val Loss: 0.0412 | CCC: 0.3755 | mACC: 0.8858224153518677
# [Epoch 146] Emo Train Loss: 44.7270 | Emo Val Loss: 125.8031 | mF1: 0.5428 | mUAR: 0.5563
#          Trait Train Loss: 0.1459 | Trait Val Loss: 0.0560 | CCC: 0.3014 | mACC: 0.8662010431289673
# [Epoch 147] Emo Train Loss: 44.3325 | Emo Val Loss: 143.3160 | mF1: 0.5454 | mUAR: 0.5511
#          Trait Train Loss: 0.1403 | Trait Val Loss: 0.0499 | CCC: 0.3213 | mACC: 0.8745226860046387
# [Epoch 148] Emo Train Loss: 43.7245 | Emo Val Loss: 127.7513 | mF1: 0.5411 | mUAR: 0.5556
#          Trait Train Loss: 0.1431 | Trait Val Loss: 0.0464 | CCC: 0.3145 | mACC: 0.8791769742965698
# [Epoch 149] Emo Train Loss: 43.0437 | Emo Val Loss: 138.2625 | mF1: 0.5505 | mUAR: 0.5568
#          Trait Train Loss: 0.1427 | Trait Val Loss: 0.0474 | CCC: 0.3529 | mACC: 0.8772789239883423
# [Epoch 150] Emo Train Loss: 44.4646 | Emo Val Loss: 111.4236 | mF1: 0.5319 | mUAR: 0.5532
#          Trait Train Loss: 0.1447 | Trait Val Loss: 0.0489 | CCC: 0.2821 | mACC: 0.8755534887313843
# [Epoch 151] Emo Train Loss: 44.6994 | Emo Val Loss: 127.5164 | mF1: 0.5468 | mUAR: 0.5553
#          Trait Train Loss: 0.1436 | Trait Val Loss: 0.0414 | CCC: 0.3561 | mACC: 0.8855680227279663
# [Epoch 152] Emo Train Loss: 43.4667 | Emo Val Loss: 123.5314 | mF1: 0.5431 | mUAR: 0.5561
#          Trait Train Loss: 0.1431 | Trait Val Loss: 0.0538 | CCC: 0.3312 | mACC: 0.8684889078140259
# [Epoch 153] Emo Train Loss: 43.3461 | Emo Val Loss: 127.7889 | mF1: 0.5420 | mUAR: 0.5564
#          Trait Train Loss: 0.1426 | Trait Val Loss: 0.0439 | CCC: 0.3507 | mACC: 0.8820565938949585
# [Epoch 154] Emo Train Loss: 43.5709 | Emo Val Loss: 130.9773 | mF1: 0.5445 | mUAR: 0.5544
#          Trait Train Loss: 0.1418 | Trait Val Loss: 0.0518 | CCC: 0.3235 | mACC: 0.8715606927871704
# [Epoch 155] Emo Train Loss: 42.9588 | Emo Val Loss: 134.2159 | mF1: 0.5437 | mUAR: 0.5571
#          Trait Train Loss: 0.1427 | Trait Val Loss: 0.0419 | CCC: 0.3547 | mACC: 0.885045051574707
# [Epoch 156] Emo Train Loss: 42.8669 | Emo Val Loss: 146.7458 | mF1: 0.5519 | mUAR: 0.5584
#          Trait Train Loss: 0.1425 | Trait Val Loss: 0.0546 | CCC: 0.2835 | mACC: 0.8680930137634277
# [Epoch 157] Emo Train Loss: 42.8851 | Emo Val Loss: 126.6399 | mF1: 0.5443 | mUAR: 0.5577
#          Trait Train Loss: 0.1383 | Trait Val Loss: 0.0423 | CCC: 0.3408 | mACC: 0.8843786120414734
# [Epoch 158] Emo Train Loss: 42.5106 | Emo Val Loss: 135.3549 | mF1: 0.5441 | mUAR: 0.5524
#          Trait Train Loss: 0.1415 | Trait Val Loss: 0.0532 | CCC: 0.2756 | mACC: 0.8706778287887573
# [Epoch 159] Emo Train Loss: 43.1805 | Emo Val Loss: 128.0656 | mF1: 0.5409 | mUAR: 0.5566
#          Trait Train Loss: 0.1416 | Trait Val Loss: 0.0420 | CCC: 0.3577 | mACC: 0.8846629858016968
# [Epoch 160] Emo Train Loss: 41.7671 | Emo Val Loss: 139.7616 | mF1: 0.5546 | mUAR: 0.5617
#          Trait Train Loss: 0.1386 | Trait Val Loss: 0.0514 | CCC: 0.3039 | mACC: 0.8722451329231262
# [Epoch 161] Emo Train Loss: 41.3983 | Emo Val Loss: 126.8175 | mF1: 0.5440 | mUAR: 0.5590
#          Trait Train Loss: 0.1425 | Trait Val Loss: 0.0453 | CCC: 0.3006 | mACC: 0.8809347152709961
# [Epoch 162] Emo Train Loss: 40.8220 | Emo Val Loss: 131.7606 | mF1: 0.5506 | mUAR: 0.5630
#          Trait Train Loss: 0.1365 | Trait Val Loss: 0.0457 | CCC: 0.3391 | mACC: 0.8793684244155884
# [Epoch 163] Emo Train Loss: 41.1773 | Emo Val Loss: 131.5589 | mF1: 0.5507 | mUAR: 0.5621
#          Trait Train Loss: 0.1383 | Trait Val Loss: 0.0505 | CCC: 0.3073 | mACC: 0.8734720945358276
# [Epoch 164] Emo Train Loss: 40.8045 | Emo Val Loss: 139.5457 | mF1: 0.5482 | mUAR: 0.5588
#          Trait Train Loss: 0.1379 | Trait Val Loss: 0.0405 | CCC: 0.3701 | mACC: 0.886951744556427
# [Epoch 165] Emo Train Loss: 41.8320 | Emo Val Loss: 142.5393 | mF1: 0.5367 | mUAR: 0.5483
#          Trait Train Loss: 0.1380 | Trait Val Loss: 0.0544 | CCC: 0.2942 | mACC: 0.8682495355606079
# [Epoch 166] Emo Train Loss: 41.4645 | Emo Val Loss: 147.3116 | mF1: 0.5512 | mUAR: 0.5586
#          Trait Train Loss: 0.1394 | Trait Val Loss: 0.0428 | CCC: 0.3558 | mACC: 0.8835231065750122
# [Epoch 167] Emo Train Loss: 41.9434 | Emo Val Loss: 120.1373 | mF1: 0.5373 | mUAR: 0.5539
#          Trait Train Loss: 0.1410 | Trait Val Loss: 0.0521 | CCC: 0.2961 | mACC: 0.8712137341499329
# [Epoch 168] Emo Train Loss: 40.8707 | Emo Val Loss: 141.8177 | mF1: 0.5512 | mUAR: 0.5584
#          Trait Train Loss: 0.1396 | Trait Val Loss: 0.0401 | CCC: 0.3729 | mACC: 0.8869583010673523
# [Epoch 169] Emo Train Loss: 39.7905 | Emo Val Loss: 130.0360 | mF1: 0.5494 | mUAR: 0.5606
#          Trait Train Loss: 0.1368 | Trait Val Loss: 0.0524 | CCC: 0.2954 | mACC: 0.8709070086479187
# [Epoch 170] Emo Train Loss: 40.6260 | Emo Val Loss: 137.8237 | mF1: 0.5513 | mUAR: 0.5609
#          Trait Train Loss: 0.1399 | Trait Val Loss: 0.0414 | CCC: 0.3748 | mACC: 0.8850830793380737
# [Epoch 171] Emo Train Loss: 40.5129 | Emo Val Loss: 142.1244 | mF1: 0.5493 | mUAR: 0.5561
#          Trait Train Loss: 0.1364 | Trait Val Loss: 0.0505 | CCC: 0.3194 | mACC: 0.873303234577179
# [Epoch 172] Emo Train Loss: 39.0342 | Emo Val Loss: 142.6440 | mF1: 0.5490 | mUAR: 0.5572
#          Trait Train Loss: 0.1353 | Trait Val Loss: 0.0464 | CCC: 0.3518 | mACC: 0.8785918354988098
# [Epoch 173] Emo Train Loss: 40.0334 | Emo Val Loss: 137.6315 | mF1: 0.5404 | mUAR: 0.5535
#          Trait Train Loss: 0.1376 | Trait Val Loss: 0.0504 | CCC: 0.3016 | mACC: 0.8735815286636353
# [Epoch 174] Emo Train Loss: 40.8996 | Emo Val Loss: 140.8170 | mF1: 0.5495 | mUAR: 0.5598
#          Trait Train Loss: 0.1344 | Trait Val Loss: 0.0435 | CCC: 0.3322 | mACC: 0.8830022811889648
# [Epoch 175] Emo Train Loss: 40.3663 | Emo Val Loss: 136.5531 | mF1: 0.5469 | mUAR: 0.5575
#          Trait Train Loss: 0.1369 | Trait Val Loss: 0.0509 | CCC: 0.3150 | mACC: 0.8727689981460571
# [Epoch 176] Emo Train Loss: 39.5396 | Emo Val Loss: 141.1486 | mF1: 0.5482 | mUAR: 0.5588
#          Trait Train Loss: 0.1367 | Trait Val Loss: 0.0439 | CCC: 0.3611 | mACC: 0.8824732899665833
# [Epoch 177] Emo Train Loss: 39.1231 | Emo Val Loss: 140.9501 | mF1: 0.5498 | mUAR: 0.5567
#          Trait Train Loss: 0.1361 | Trait Val Loss: 0.0531 | CCC: 0.2955 | mACC: 0.8701239824295044
# [Epoch 178] Emo Train Loss: 38.4327 | Emo Val Loss: 131.9241 | mF1: 0.5390 | mUAR: 0.5568
#          Trait Train Loss: 0.1384 | Trait Val Loss: 0.0403 | CCC: 0.3622 | mACC: 0.8872109651565552
# [Epoch 179] Emo Train Loss: 39.8645 | Emo Val Loss: 158.5546 | mF1: 0.5518 | mUAR: 0.5570
#          Trait Train Loss: 0.1429 | Trait Val Loss: 0.0592 | CCC: 0.2892 | mACC: 0.8621695637702942
# [Epoch 180] Emo Train Loss: 39.6123 | Emo Val Loss: 144.0432 | mF1: 0.5489 | mUAR: 0.5585
#          Trait Train Loss: 0.1346 | Trait Val Loss: 0.0446 | CCC: 0.3431 | mACC: 0.8814367055892944
# [Epoch 181] Emo Train Loss: 39.0319 | Emo Val Loss: 144.7536 | mF1: 0.5460 | mUAR: 0.5532
#          Trait Train Loss: 0.1342 | Trait Val Loss: 0.0467 | CCC: 0.3439 | mACC: 0.8787983059883118
# [Epoch 182] Emo Train Loss: 38.1461 | Emo Val Loss: 137.8164 | mF1: 0.5528 | mUAR: 0.5617
#          Trait Train Loss: 0.1336 | Trait Val Loss: 0.0428 | CCC: 0.3454 | mACC: 0.8839667439460754
# [Epoch 183] Emo Train Loss: 38.1019 | Emo Val Loss: 141.7469 | mF1: 0.5492 | mUAR: 0.5604
#          Trait Train Loss: 0.1326 | Trait Val Loss: 0.0469 | CCC: 0.3480 | mACC: 0.8779631853103638
# [Epoch 184] Emo Train Loss: 38.0642 | Emo Val Loss: 128.4814 | mF1: 0.5458 | mUAR: 0.5600
#          Trait Train Loss: 0.1337 | Trait Val Loss: 0.0467 | CCC: 0.3198 | mACC: 0.8787604570388794
# [Epoch 185] Emo Train Loss: 38.8726 | Emo Val Loss: 143.9202 | mF1: 0.5427 | mUAR: 0.5508
#          Trait Train Loss: 0.1330 | Trait Val Loss: 0.0454 | CCC: 0.3387 | mACC: 0.8800838589668274
# [Epoch 186] Emo Train Loss: 38.6302 | Emo Val Loss: 135.2352 | mF1: 0.5437 | mUAR: 0.5573
#          Trait Train Loss: 0.1363 | Trait Val Loss: 0.0491 | CCC: 0.3250 | mACC: 0.8752506375312805
# [Epoch 187] Emo Train Loss: 38.0695 | Emo Val Loss: 149.5688 | mF1: 0.5451 | mUAR: 0.5518
#          Trait Train Loss: 0.1358 | Trait Val Loss: 0.0415 | CCC: 0.3512 | mACC: 0.8853523135185242
# [Epoch 188] Emo Train Loss: 38.2633 | Emo Val Loss: 126.8985 | mF1: 0.5378 | mUAR: 0.5542
#          Trait Train Loss: 0.1370 | Trait Val Loss: 0.0528 | CCC: 0.3023 | mACC: 0.8704608678817749
# [Epoch 189] Emo Train Loss: 38.0938 | Emo Val Loss: 146.3630 | mF1: 0.5444 | mUAR: 0.5525
#          Trait Train Loss: 0.1356 | Trait Val Loss: 0.0411 | CCC: 0.3788 | mACC: 0.8859650492668152
# [Epoch 190] Emo Train Loss: 38.0886 | Emo Val Loss: 137.3924 | mF1: 0.5458 | mUAR: 0.5556
#          Trait Train Loss: 0.1345 | Trait Val Loss: 0.0480 | CCC: 0.3007 | mACC: 0.8767064809799194
# [Epoch 191] Emo Train Loss: 36.2335 | Emo Val Loss: 144.5135 | mF1: 0.5486 | mUAR: 0.5581
#          Trait Train Loss: 0.1344 | Trait Val Loss: 0.0434 | CCC: 0.3465 | mACC: 0.8831526637077332
# [Epoch 192] Emo Train Loss: 37.2537 | Emo Val Loss: 140.3964 | mF1: 0.5433 | mUAR: 0.5517
#          Trait Train Loss: 0.1311 | Trait Val Loss: 0.0477 | CCC: 0.3302 | mACC: 0.8766463994979858
# [Epoch 193] Emo Train Loss: 36.7746 | Emo Val Loss: 142.6227 | mF1: 0.5455 | mUAR: 0.5562
#          Trait Train Loss: 0.1339 | Trait Val Loss: 0.0414 | CCC: 0.3617 | mACC: 0.8856670260429382
# [Epoch 194] Emo Train Loss: 37.3422 | Emo Val Loss: 143.6739 | mF1: 0.5463 | mUAR: 0.5560
#          Trait Train Loss: 0.1324 | Trait Val Loss: 0.0481 | CCC: 0.3229 | mACC: 0.8762596249580383
# [Epoch 195] Emo Train Loss: 37.1711 | Emo Val Loss: 150.1630 | mF1: 0.5478 | mUAR: 0.5551
#          Trait Train Loss: 0.1337 | Trait Val Loss: 0.0439 | CCC: 0.3434 | mACC: 0.8823712468147278
# [Epoch 196] Emo Train Loss: 36.4172 | Emo Val Loss: 133.3398 | mF1: 0.5356 | mUAR: 0.5525
#          Trait Train Loss: 0.1341 | Trait Val Loss: 0.0500 | CCC: 0.2786 | mACC: 0.8739298582077026
# [Epoch 197] Emo Train Loss: 37.0233 | Emo Val Loss: 147.8646 | mF1: 0.5484 | mUAR: 0.5555
#          Trait Train Loss: 0.1329 | Trait Val Loss: 0.0407 | CCC: 0.3903 | mACC: 0.8864639401435852
# [Epoch 198] Emo Train Loss: 35.3374 | Emo Val Loss: 136.6852 | mF1: 0.5427 | mUAR: 0.5560
#          Trait Train Loss: 0.1297 | Trait Val Loss: 0.0486 | CCC: 0.3147 | mACC: 0.8763257265090942
# [Epoch 199] Emo Train Loss: 36.9079 | Emo Val Loss: 144.8637 | mF1: 0.5469 | mUAR: 0.5573
#          Trait Train Loss: 0.1294 | Trait Val Loss: 0.0469 | CCC: 0.3499 | mACC: 0.8779966235160828
# [Epoch 200] Emo Train Loss: 36.2302 | Emo Val Loss: 143.7284 | mF1: 0.5445 | mUAR: 0.5545
#          Trait Train Loss: 0.1307 | Trait Val Loss: 0.0460 | CCC: 0.3310 | mACC: 0.879169762134552

# %%
# Save model weights
torch.save(model.state_dict(), 'models_checkpoints/multitask_fusion_model.pth')
