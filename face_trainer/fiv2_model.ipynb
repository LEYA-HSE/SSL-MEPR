# %%
import pickle
import torch
import torch.nn as nn
import pandas as pd
from pathlib import Path
from tqdm import tqdm
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# %%
# ============ Load Annotations ============
def load_labels(pkl_path):
    with open(pkl_path, 'rb') as f:
        data = pickle.load(f, encoding='latin1')

    #trait_keys = ['extraversion', 'neuroticism', 'agreeableness', 'conscientiousness', 'openness', 'interview']
    trait_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']  # OCEAN order

    video_names = list(data['extraversion'].keys())

    records = []
    for name in video_names:
        name = name[:-4]  # strip extension
        record = {'video_name': name}
        for key in trait_keys:
            record[key] = data[key][name + '.mp4']
        records.append(record)

    return pd.DataFrame(records)

train_df = load_labels('Embeddings_emonext/fiv2_embeddings/annotation_training.pkl')
test_df = load_labels('Embeddings_emonext/fiv2_embeddings/annotation_test.pkl')

# %%
train_df.head()
# Out:
#         video_name  openness  conscientiousness  extraversion  agreeableness  \
# 0  J4GQm9j0JZ0.003  0.488889           0.601942      0.523364       0.626374
# 1  zEyRyTnIw5I.005  0.366667           0.582524      0.345794       0.472527
# 2  nskJh7v6v1U.004  0.511111           0.485437      0.252336       0.406593
# 3  6wHQsN5g2RM.000  0.377778           0.398058      0.457944       0.505495
# 4  dQOeQYWIgm8.000  0.622222           0.621359      0.607477       0.406593
#
#    neuroticism
# 0     0.552083
# 1     0.375000
# 2     0.291667
# 3     0.489583
# 4     0.489583

# %%
# ============ Load Embeddings ============
def load_embeddings(df, emb_dir):
    X, y, lengths = [], [], []
    trait_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
    for folder in Path(emb_dir).iterdir():
        for pt_file in folder.glob('*.pt'):
            video_id = pt_file.stem
            if video_id not in df['video_name'].values:
                continue
            try:
                emb = torch.load(pt_file, weights_only=True)
                if isinstance(emb, dict):
                    emb = emb['emb']
                if torch.isnan(emb).any() or emb.shape != (30, 1024):
                    continue
            except Exception:
                continue

            traits = df[df['video_name'] == video_id][trait_keys].values[0].astype('float32')
            X.append(emb)
            y.append(torch.tensor(traits))
            lengths.append(torch.tensor(emb.shape[0]))

    return torch.stack(X), torch.stack(y), torch.stack(lengths)

X_train, y_train, lengths_train = load_embeddings(train_df, 'Embeddings_emonext/fiv2_embeddings/train')
X_test, y_test, lengths_test = load_embeddings(test_df, 'Embeddings_emonext/fiv2_embeddings/test')

# %%
# ============ Data Loaders ============
train_loader = DataLoader(TensorDataset(X_train, y_train, lengths_train), batch_size=512, shuffle=True)
val_loader = DataLoader(TensorDataset(X_test, y_test, lengths_test), batch_size=512)

# %%
# ============ Model ============
class TransformerClassifier(nn.Module):
    def __init__(self, input_dim=1024, d_model=512, num_layers=3, n_heads=8, dropout=0.2, num_classes=5, max_len=30):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embed = nn.Parameter(torch.randn(1, max_len, d_model))
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, dim_feedforward=d_model * 4, dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x, lengths):
        x = self.input_proj(x) + self.pos_embed[:, :x.size(1)]
        x = self.encoder(x)
        mask = torch.arange(x.size(1), device=lengths.device)[None, :] < lengths[:, None]
        mask = mask.float().unsqueeze(2)
        summed = (x * mask).sum(dim=1)
        count = mask.sum(dim=1).clamp(min=1)
        pooled = summed / count
        return self.fc(self.dropout(pooled))

# %%
from sklearn.metrics import mean_absolute_error

# ============ Training ============
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TransformerClassifier(input_dim=1024, num_classes=5).to(DEVICE)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

def ccc(y_true, y_pred):
    """
    This function calculates loss based on concordance correlation coefficient of two series: 'ser1' and 'ser2'
    TensorFlow methods are used
    """

    y_true_mean = np.mean(y_true)
    y_pred_mean = np.mean(y_pred)

    y_true_var = np.mean(np.square(y_true-y_true_mean))
    y_pred_var = np.mean(np.square(y_pred-y_pred_mean))

    cov = np.mean((y_true-y_true_mean)*(y_pred-y_pred_mean))

    ccc = np.multiply(2., cov) / (y_true_var + y_pred_var + np.square(y_true_mean - y_pred_mean))
    ccc_loss=np.mean(ccc)
    return ccc_loss

def acc_func(trues, preds):
    # print('acc', trues, preds)
    acc = []
    for i in range(5):
        acc.append(np.abs(trues - preds))
    acc = 1 - np.asarray(acc)
    return np.mean(acc)

for epoch in range(1, 101):
    model.train()
    total_loss = 0
    for xb, yb, lb in train_loader:
        xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
        optimizer.zero_grad()
        logits = model(xb, lb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    model.eval()
    val_loss, preds, targets = 0, [], []
    with torch.no_grad():
        for xb, yb, lb in val_loader:
            xb, yb, lb = xb.to(DEVICE), yb.to(DEVICE), lb.to(DEVICE)
            logits = model(xb, lb)
            val_loss += criterion(logits, yb).item()
            preds.append(logits.cpu())
            targets.append(yb.cpu())

    preds = torch.cat(preds).numpy()
    targets = torch.cat(targets).numpy()
    
    ccc_scores = [ccc(targets[:, i], preds[:, i]) for i in range(preds.shape[1])]
    mean_ccc = np.mean(ccc_scores)
    
    acc_scores = [acc_func(targets[:, i], preds[:, i]) for i in range(preds.shape[1])]
    mean_acc = np.mean(acc_scores)

    print(f"[Epoch {epoch}] Train Loss: {total_loss:.4f} | Val Loss: {val_loss:.4f} | Mean CCC: {mean_ccc:.4f} | Mean acc: {mean_acc:.4f}")
# Out:
# [Epoch 1] Train Loss: 1.1371 | Val Loss: 0.2122 | Mean CCC: 0.0295 | Mean acc: 0.8150
# [Epoch 2] Train Loss: 0.5763 | Val Loss: 0.1112 | Mean CCC: 0.0705 | Mean acc: 0.8651
# [Epoch 3] Train Loss: 0.4791 | Val Loss: 0.1005 | Mean CCC: 0.1101 | Mean acc: 0.8753
# [Epoch 4] Train Loss: 0.4362 | Val Loss: 0.0839 | Mean CCC: 0.1480 | Mean acc: 0.8839
# [Epoch 5] Train Loss: 0.4078 | Val Loss: 0.0843 | Mean CCC: 0.1649 | Mean acc: 0.8849
# [Epoch 6] Train Loss: 0.3905 | Val Loss: 0.0810 | Mean CCC: 0.1842 | Mean acc: 0.8866
# [Epoch 7] Train Loss: 0.3723 | Val Loss: 0.0801 | Mean CCC: 0.1962 | Mean acc: 0.8873
# [Epoch 8] Train Loss: 0.3555 | Val Loss: 0.0804 | Mean CCC: 0.2048 | Mean acc: 0.8874
# [Epoch 9] Train Loss: 0.3430 | Val Loss: 0.0779 | Mean CCC: 0.2177 | Mean acc: 0.8886
# [Epoch 10] Train Loss: 0.3315 | Val Loss: 0.0782 | Mean CCC: 0.2229 | Mean acc: 0.8887
# [Epoch 11] Train Loss: 0.3237 | Val Loss: 0.0777 | Mean CCC: 0.2289 | Mean acc: 0.8890
# [Epoch 12] Train Loss: 0.3187 | Val Loss: 0.0772 | Mean CCC: 0.2354 | Mean acc: 0.8894
# [Epoch 13] Train Loss: 0.3108 | Val Loss: 0.0767 | Mean CCC: 0.2402 | Mean acc: 0.8899
# [Epoch 14] Train Loss: 0.3039 | Val Loss: 0.0767 | Mean CCC: 0.2462 | Mean acc: 0.8899
# [Epoch 15] Train Loss: 0.2989 | Val Loss: 0.0753 | Mean CCC: 0.2534 | Mean acc: 0.8907
# [Epoch 16] Train Loss: 0.2926 | Val Loss: 0.0745 | Mean CCC: 0.2579 | Mean acc: 0.8912
# [Epoch 17] Train Loss: 0.2898 | Val Loss: 0.0750 | Mean CCC: 0.2626 | Mean acc: 0.8911
# [Epoch 18] Train Loss: 0.2812 | Val Loss: 0.0753 | Mean CCC: 0.2655 | Mean acc: 0.8909
# [Epoch 19] Train Loss: 0.2846 | Val Loss: 0.0750 | Mean CCC: 0.2693 | Mean acc: 0.8909
# [Epoch 20] Train Loss: 0.2795 | Val Loss: 0.0752 | Mean CCC: 0.2708 | Mean acc: 0.8908
# [Epoch 21] Train Loss: 0.2753 | Val Loss: 0.0731 | Mean CCC: 0.2797 | Mean acc: 0.8922
# [Epoch 22] Train Loss: 0.2708 | Val Loss: 0.0725 | Mean CCC: 0.2839 | Mean acc: 0.8926
# [Epoch 23] Train Loss: 0.2680 | Val Loss: 0.0730 | Mean CCC: 0.2866 | Mean acc: 0.8924
# [Epoch 24] Train Loss: 0.2645 | Val Loss: 0.0722 | Mean CCC: 0.2903 | Mean acc: 0.8929
# [Epoch 25] Train Loss: 0.2637 | Val Loss: 0.0733 | Mean CCC: 0.2878 | Mean acc: 0.8923
# [Epoch 26] Train Loss: 0.2637 | Val Loss: 0.0717 | Mean CCC: 0.2970 | Mean acc: 0.8932
# [Epoch 27] Train Loss: 0.2605 | Val Loss: 0.0721 | Mean CCC: 0.2968 | Mean acc: 0.8932
# [Epoch 28] Train Loss: 0.2587 | Val Loss: 0.0713 | Mean CCC: 0.3023 | Mean acc: 0.8936
# [Epoch 29] Train Loss: 0.2574 | Val Loss: 0.0715 | Mean CCC: 0.3044 | Mean acc: 0.8935
# [Epoch 30] Train Loss: 0.2562 | Val Loss: 0.0712 | Mean CCC: 0.3060 | Mean acc: 0.8936
# [Epoch 31] Train Loss: 0.2554 | Val Loss: 0.0706 | Mean CCC: 0.3106 | Mean acc: 0.8941
# [Epoch 32] Train Loss: 0.2539 | Val Loss: 0.0715 | Mean CCC: 0.3115 | Mean acc: 0.8938
# [Epoch 33] Train Loss: 0.2523 | Val Loss: 0.0701 | Mean CCC: 0.3173 | Mean acc: 0.8945
# [Epoch 34] Train Loss: 0.2522 | Val Loss: 0.0704 | Mean CCC: 0.3171 | Mean acc: 0.8944
# [Epoch 35] Train Loss: 0.2475 | Val Loss: 0.0699 | Mean CCC: 0.3202 | Mean acc: 0.8947
# [Epoch 36] Train Loss: 0.2495 | Val Loss: 0.0710 | Mean CCC: 0.3211 | Mean acc: 0.8941
# [Epoch 37] Train Loss: 0.2469 | Val Loss: 0.0697 | Mean CCC: 0.3262 | Mean acc: 0.8949
# [Epoch 38] Train Loss: 0.2476 | Val Loss: 0.0704 | Mean CCC: 0.3255 | Mean acc: 0.8945
# [Epoch 39] Train Loss: 0.2480 | Val Loss: 0.0716 | Mean CCC: 0.3248 | Mean acc: 0.8938
# [Epoch 40] Train Loss: 0.2486 | Val Loss: 0.0705 | Mean CCC: 0.3286 | Mean acc: 0.8944
# [Epoch 41] Train Loss: 0.2481 | Val Loss: 0.0702 | Mean CCC: 0.3319 | Mean acc: 0.8947
# [Epoch 42] Train Loss: 0.2477 | Val Loss: 0.0693 | Mean CCC: 0.3347 | Mean acc: 0.8952
# [Epoch 43] Train Loss: 0.2446 | Val Loss: 0.0704 | Mean CCC: 0.3343 | Mean acc: 0.8946
# [Epoch 44] Train Loss: 0.2438 | Val Loss: 0.0686 | Mean CCC: 0.3402 | Mean acc: 0.8957
# [Epoch 45] Train Loss: 0.2423 | Val Loss: 0.0693 | Mean CCC: 0.3384 | Mean acc: 0.8953
# [Epoch 46] Train Loss: 0.2400 | Val Loss: 0.0692 | Mean CCC: 0.3410 | Mean acc: 0.8954
# [Epoch 47] Train Loss: 0.2416 | Val Loss: 0.0696 | Mean CCC: 0.3408 | Mean acc: 0.8952
# [Epoch 48] Train Loss: 0.2429 | Val Loss: 0.0689 | Mean CCC: 0.3456 | Mean acc: 0.8957
# [Epoch 49] Train Loss: 0.2393 | Val Loss: 0.0705 | Mean CCC: 0.3415 | Mean acc: 0.8946
# [Epoch 50] Train Loss: 0.2401 | Val Loss: 0.0692 | Mean CCC: 0.3452 | Mean acc: 0.8956
# [Epoch 51] Train Loss: 0.2382 | Val Loss: 0.0687 | Mean CCC: 0.3467 | Mean acc: 0.8958
# [Epoch 52] Train Loss: 0.2402 | Val Loss: 0.0684 | Mean CCC: 0.3480 | Mean acc: 0.8961
# [Epoch 53] Train Loss: 0.2370 | Val Loss: 0.0683 | Mean CCC: 0.3508 | Mean acc: 0.8960
# [Epoch 54] Train Loss: 0.2363 | Val Loss: 0.0678 | Mean CCC: 0.3536 | Mean acc: 0.8963
# [Epoch 55] Train Loss: 0.2424 | Val Loss: 0.0693 | Mean CCC: 0.3497 | Mean acc: 0.8954
# [Epoch 56] Train Loss: 0.2398 | Val Loss: 0.0679 | Mean CCC: 0.3557 | Mean acc: 0.8962
# [Epoch 57] Train Loss: 0.2365 | Val Loss: 0.0675 | Mean CCC: 0.3610 | Mean acc: 0.8965
# [Epoch 58] Train Loss: 0.2352 | Val Loss: 0.0675 | Mean CCC: 0.3590 | Mean acc: 0.8966
# [Epoch 59] Train Loss: 0.2343 | Val Loss: 0.0680 | Mean CCC: 0.3587 | Mean acc: 0.8964
# [Epoch 60] Train Loss: 0.2345 | Val Loss: 0.0676 | Mean CCC: 0.3587 | Mean acc: 0.8966
# [Epoch 61] Train Loss: 0.2361 | Val Loss: 0.0690 | Mean CCC: 0.3580 | Mean acc: 0.8958
# [Epoch 62] Train Loss: 0.2335 | Val Loss: 0.0680 | Mean CCC: 0.3615 | Mean acc: 0.8965
# [Epoch 63] Train Loss: 0.2343 | Val Loss: 0.0672 | Mean CCC: 0.3639 | Mean acc: 0.8970
# [Epoch 64] Train Loss: 0.2326 | Val Loss: 0.0673 | Mean CCC: 0.3648 | Mean acc: 0.8968
# [Epoch 65] Train Loss: 0.2312 | Val Loss: 0.0668 | Mean CCC: 0.3688 | Mean acc: 0.8971
# [Epoch 66] Train Loss: 0.2311 | Val Loss: 0.0698 | Mean CCC: 0.3582 | Mean acc: 0.8953
# [Epoch 67] Train Loss: 0.2336 | Val Loss: 0.0669 | Mean CCC: 0.3709 | Mean acc: 0.8971
# [Epoch 68] Train Loss: 0.2313 | Val Loss: 0.0669 | Mean CCC: 0.3724 | Mean acc: 0.8972
# [Epoch 69] Train Loss: 0.2306 | Val Loss: 0.0670 | Mean CCC: 0.3731 | Mean acc: 0.8971
# [Epoch 70] Train Loss: 0.2305 | Val Loss: 0.0669 | Mean CCC: 0.3720 | Mean acc: 0.8972
# [Epoch 71] Train Loss: 0.2308 | Val Loss: 0.0677 | Mean CCC: 0.3693 | Mean acc: 0.8968
# [Epoch 72] Train Loss: 0.2303 | Val Loss: 0.0663 | Mean CCC: 0.3775 | Mean acc: 0.8976
# [Epoch 73] Train Loss: 0.2279 | Val Loss: 0.0670 | Mean CCC: 0.3758 | Mean acc: 0.8972
# [Epoch 74] Train Loss: 0.2291 | Val Loss: 0.0721 | Mean CCC: 0.3602 | Mean acc: 0.8936
# [Epoch 75] Train Loss: 0.2323 | Val Loss: 0.0663 | Mean CCC: 0.3791 | Mean acc: 0.8976
# [Epoch 76] Train Loss: 0.2324 | Val Loss: 0.0673 | Mean CCC: 0.3758 | Mean acc: 0.8969
# [Epoch 77] Train Loss: 0.2301 | Val Loss: 0.0664 | Mean CCC: 0.3764 | Mean acc: 0.8974
# [Epoch 78] Train Loss: 0.2281 | Val Loss: 0.0681 | Mean CCC: 0.3736 | Mean acc: 0.8966
# [Epoch 79] Train Loss: 0.2290 | Val Loss: 0.0662 | Mean CCC: 0.3796 | Mean acc: 0.8978
# [Epoch 80] Train Loss: 0.2293 | Val Loss: 0.0659 | Mean CCC: 0.3838 | Mean acc: 0.8979
# [Epoch 81] Train Loss: 0.2252 | Val Loss: 0.0679 | Mean CCC: 0.3761 | Mean acc: 0.8967
# [Epoch 82] Train Loss: 0.2277 | Val Loss: 0.0662 | Mean CCC: 0.3831 | Mean acc: 0.8975
# [Epoch 83] Train Loss: 0.2268 | Val Loss: 0.0662 | Mean CCC: 0.3815 | Mean acc: 0.8978
# [Epoch 84] Train Loss: 0.2255 | Val Loss: 0.0682 | Mean CCC: 0.3788 | Mean acc: 0.8965
# [Epoch 85] Train Loss: 0.2255 | Val Loss: 0.0661 | Mean CCC: 0.3846 | Mean acc: 0.8979
# [Epoch 86] Train Loss: 0.2253 | Val Loss: 0.0683 | Mean CCC: 0.3767 | Mean acc: 0.8963
# [Epoch 87] Train Loss: 0.2262 | Val Loss: 0.0657 | Mean CCC: 0.3895 | Mean acc: 0.8979
# [Epoch 88] Train Loss: 0.2240 | Val Loss: 0.0666 | Mean CCC: 0.3854 | Mean acc: 0.8976
# [Epoch 89] Train Loss: 0.2239 | Val Loss: 0.0654 | Mean CCC: 0.3922 | Mean acc: 0.8983
# [Epoch 90] Train Loss: 0.2237 | Val Loss: 0.0674 | Mean CCC: 0.3843 | Mean acc: 0.8970
# [Epoch 91] Train Loss: 0.2241 | Val Loss: 0.0666 | Mean CCC: 0.3906 | Mean acc: 0.8976
# [Epoch 92] Train Loss: 0.2235 | Val Loss: 0.0666 | Mean CCC: 0.3857 | Mean acc: 0.8976
# [Epoch 93] Train Loss: 0.2223 | Val Loss: 0.0682 | Mean CCC: 0.3848 | Mean acc: 0.8966
# [Epoch 94] Train Loss: 0.2229 | Val Loss: 0.0655 | Mean CCC: 0.3920 | Mean acc: 0.8980
# [Epoch 95] Train Loss: 0.2262 | Val Loss: 0.0689 | Mean CCC: 0.3839 | Mean acc: 0.8960
# [Epoch 96] Train Loss: 0.2226 | Val Loss: 0.0653 | Mean CCC: 0.3963 | Mean acc: 0.8984
# [Epoch 97] Train Loss: 0.2221 | Val Loss: 0.0654 | Mean CCC: 0.3952 | Mean acc: 0.8984
# [Epoch 98] Train Loss: 0.2213 | Val Loss: 0.0666 | Mean CCC: 0.3960 | Mean acc: 0.8977
# [Epoch 99] Train Loss: 0.2219 | Val Loss: 0.0658 | Mean CCC: 0.3962 | Mean acc: 0.8981
# [Epoch 100] Train Loss: 0.2198 | Val Loss: 0.0657 | Mean CCC: 0.3940 | Mean acc: 0.8982

# %%
# Save weights
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
}, "fiv2_best_checkpoint.pth")
